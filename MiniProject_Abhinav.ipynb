# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataset = pd.read_csv('Train_123.csv')

# %%
dataset.shape
# Out:
# (8523, 12)

# %%
dataset.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
dataset.isnull().sum().sort_values(ascending = False)
# Out:
# Outlet_Size                  2410
# Item_Weight                  1463
# Item_Identifier                 0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
dataset.Item_Weight.describe()
# Out:
# count    7060.000000
# mean       12.857645
# std         4.643456
# min         4.555000
# 25%         8.773750
# 50%        12.600000
# 75%        16.850000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %%
dataset['Item_Weight'].fillna(dataset['Item_Weight'].mean(),inplace=True)

# %%
dataset['Outlet_Size'].describe()
# Out:
# count       6113
# unique         3
# top       Medium
# freq        2793
# Name: Outlet_Size, dtype: object

# %%
dataset['Outlet_Size'].fillna('Medium', inplace = True)

# %%
dataset.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
dataset.isnull().sum().sort_values(ascending = False)
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
#from sklearn.preprocessing import LabelEncoder
#Outlet_Size = ('Medium','Small', 'High')

#dataset = pd.DataFrame(dataset, columns = ['Outlet_Size'])

# %%
#labelencoder = LabelEncoder()
#dataset['outlet_size_Cat'] = labelencoder.fit_transform(dataset['Outlet_Size'])

# %%
dataset.head(25)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15     9.300000          Low Fat         0.016047
# 1            DRC01     5.920000          Regular         0.019278
# 2            FDN15    17.500000          Low Fat         0.016760
# 3            FDX07    19.200000          Regular         0.000000
# 4            NCD19     8.930000          Low Fat         0.000000
# 5            FDP36    10.395000          Regular         0.000000
# 6            FDO10    13.650000          Regular         0.012741
# 7            FDP10    12.857645          Low Fat         0.127470
# 8            FDH17    16.200000          Regular         0.016687
# 9            FDU28    19.200000          Regular         0.094450
# 10           FDY07    11.800000          Low Fat         0.000000
# 11           FDA03    18.500000          Regular         0.045464
# 12           FDX32    15.100000          Regular         0.100014
# ...

# %%
#dataset.loc[:,'outlet_size_Cat'].fillna(2,inplace=True)

# %%
import seaborn as sns
dataset.Item_Visibility.head()
# Out:
# 0    0.016047
# 1    0.019278
# 2    0.016760
# 3    0.000000
# 4    0.000000
# Name: Item_Visibility, dtype: float64

# %%
sns.countplot(dataset['Item_Type'])
# Out:
# C:\ananconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Item_Type', ylabel='count'>

# %%
dataset.pivot_table('Item_Outlet_Sales','Item_Type',aggfunc=np.average).plot.bar()
# Out:
# <AxesSubplot:xlabel='Item_Type'>

# %%
dataset.Item_Fat_Content.unique()
def fun(x):
  if x=='Low Fat' or x=='LF' or x=='low fat':
    return(0)
  else:
    return(1)

dataset['Item_Fat_Content']=dataset['Item_Fat_Content'].apply(fun)

# %%
dataset.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           FDA15     9.300000                 0         0.016047
# 1           DRC01     5.920000                 1         0.019278
# 2           FDN15    17.500000                 0         0.016760
# 3           FDX07    19.200000                 1         0.000000
# 4           NCD19     8.930000                 0         0.000000
# 5           FDP36    10.395000                 1         0.000000
# 6           FDO10    13.650000                 1         0.012741
# 7           FDP10    12.857645                 0         0.127470
# 8           FDH17    16.200000                 1         0.016687
# 9           FDU28    19.200000                 1         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
#from sklearn.preprocessing import LabelEncoder
#Outlet_Size = ('Medium','Small', 'High')

#dataset1 = pd.DataFrame(dataset, columns = ['Outlet_Size'])

#labelencoder = LabelEncoder()
#dataset['outlet_size_Cat'] = labelencoder.fit_transform(dataset['Outlet_Size'])

# %%
dataset = pd.get_dummies(dataset, columns = ["Outlet_Size", "Outlet_Location_Type", "Outlet_Type"],drop_first = True)

# %%
dataset.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30                 0         0.016047
# 1           DRC01         5.92                 1         0.019278
# 2           FDN15        17.50                 0         0.016760
# 3           FDX07        19.20                 1         0.000000
# 4           NCD19         8.93                 0         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year  Item_Outlet_Sales  Outlet_Size_Medium  \
# 0                       1999          3735.1380                   1
# 1                       2009           443.4228                   1
# ...

# %%
dataset.pivot_table('Item_Outlet_Sales','Outlet_Establishment_Year').plot.bar()
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year'>

# %%
dataset.pivot_table('Item_Outlet_Sales','Outlet_Identifier').plot.bar()
# Out:
# <AxesSubplot:xlabel='Outlet_Identifier'>

# %%
dataset['Outlet_Identifier'].unique()
# Out:
# array(['OUT049', 'OUT018', 'OUT010', 'OUT013', 'OUT027', 'OUT045',
#        'OUT017', 'OUT046', 'OUT035', 'OUT019'], dtype=object)

# %%
dataset=pd.get_dummies(dataset, columns = ['Outlet_Identifier'],drop_first = True)

# %%
dataset.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30                 1         0.016047
# 1           DRC01         5.92                 1         0.019278
# 2           FDN15        17.50                 1         0.016760
# 3           FDX07        19.20                 1         0.000000
# 4           NCD19         8.93                 1         0.000000
#
#                Item_Type  Item_MRP  Outlet_Establishment_Year  \
# 0                  Dairy  249.8092                       1999
# 1            Soft Drinks   48.2692                       2009
# 2                   Meat  141.6180                       1999
# 3  Fruits and Vegetables  182.0950                       1998
# 4              Household   53.8614                       1987
#
#    Item_Outlet_Sales  Outlet_Size_Medium  Outlet_Size_Small  ...  \
# 0          3735.1380                   1                  0  ...
# ...

# %%
dataset['Item_Fat_Content'].unique()
# Out:
# array([1], dtype=int64)

# %%
def fun(x):
  if x=='Low Fat' or x=='LF' or x=='low fat':
    return(0)
  else:
    return(1)

# %%
dataset['Item_Fat_Content']=dataset['Item_Fat_Content'].apply(fun)

# %%
dataset.head(5)
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30                 1         0.016047
# 1           DRC01         5.92                 1         0.019278
# 2           FDN15        17.50                 1         0.016760
# 3           FDX07        19.20                 1         0.000000
# 4           NCD19         8.93                 1         0.000000
#
#                Item_Type  Item_MRP  Outlet_Establishment_Year  \
# 0                  Dairy  249.8092                       1999
# 1            Soft Drinks   48.2692                       2009
# 2                   Meat  141.6180                       1999
# 3  Fruits and Vegetables  182.0950                       1998
# 4              Household   53.8614                       1987
#
#    Item_Outlet_Sales  Outlet_Size_Medium  Outlet_Size_Small  ...  \
# 0          3735.1380                   1                  0  ...
# ...

# %%
dataset.isnull().sum().sort_values(ascending = False)
# Out:
# Item_Identifier                  0
# Item_Weight                      0
# Outlet_Identifier_OUT046         0
# Outlet_Identifier_OUT045         0
# Outlet_Identifier_OUT035         0
# Outlet_Identifier_OUT027         0
# Outlet_Identifier_OUT019         0
# Outlet_Identifier_OUT018         0
# Outlet_Identifier_OUT017         0
# Outlet_Identifier_OUT013         0
# Outlet_Type_Supermarket Type3    0
# Outlet_Type_Supermarket Type2    0
# Outlet_Type_Supermarket Type1    0
# Outlet_Location_Type_Tier 3      0
# Outlet_Location_Type_Tier 2      0
# Outlet_Size_Small                0
# Outlet_Size_Medium               0
# Item_Outlet_Sales                0
# Outlet_Establishment_Year        0
# Item_MRP                         0
# Item_Type                        0
# Item_Visibility                  0
# Item_Fat_Content                 0
# Outlet_Identifier_OUT049         0
# dtype: int64

# %%
plt.scatter(dataset['Item_Visibility'],dataset['Item_Outlet_Sales'])

# %%
x = dataset.drop(['Item_Identifier','Item_Type','Outlet_Establishment_Year','Item_Outlet_Sales'],axis=1)
y = dataset['Item_Outlet_Sales']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

# %%
#sc = StandardScaler()

# %%
#x_train = sc.fit_transform(x_train)
#x_test = sc.transform(x_test)

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor(n_estimators= 1000,
          max_depth= 3,
          min_samples_split= 5,
          learning_rate = 0.01,
          loss = 'ls')

# %%
gbr.fit(x_train, y_train)
# Out:
# C:\ananconda\lib\site-packages\sklearn\ensemble\_gb.py:286: FutureWarning: The loss 'ls' was deprecated in v1.0 and will be removed in version 1.2. Use 'squared_error' which is equivalent.
#   warnings.warn(
# GradientBoostingRegressor(learning_rate=0.01, loss='ls', min_samples_split=5,
#                           n_estimators=1000)

# %%
predictions = gbr.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
score = mean_absolute_error(y_test, predictions) 
print('MAE:', score)
print("model accuracy: {}".format(r2_score(y_test, predictions)))
# Out:
# MAE: 764.9824842362823
# model accuracy: 0.6004518399564232
