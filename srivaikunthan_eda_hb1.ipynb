# %%
#First we import the libraries needed to perfrom some basic operations and EDA-Srivaikunthan

import numpy as np
import matplotlib
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')

# %%
#reading  the excel.file
df = pd.read_excel("/H-1B_Disclosure_Data_FY2019.xlsx", usecols=["CASE_STATUS", "VISA_CLASS","JOB_TITLE","SOC_TITLE","FULL_TIME_POSITION","EMPLOYER_NAME","EMPLOYER_CITY","EMPLOYER_STATE","PREVAILING_WAGE_1","CASE_SUBMITTED"],nrows=600000 )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# f:\sem6\EDA_mainproject_srivaikunthan\srivaikunthan_eda_hb1.ipynb Cell 2' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/f%3A/sem6/EDA_mainproject_srivaikunthan/srivaikunthan_eda_hb1.ipynb#ch0000001?line=0'>1</a> #reading  the excel.file
# ----> <a href='vscode-notebook-cell:/f%3A/sem6/EDA_mainproject_srivaikunthan/srivaikunthan_eda_hb1.ipynb#ch0000001?line=1'>2</a> df = pd.read_excel("F:\sem6\EDA_mainproject_srivaikunthan\H-1B_Disclosure_Data_FY2019.xlsx", usecols=["CASE_STATUS", "VISA_CLASS","JOB_TITLE","SOC_TITLE","FULL_TIME_POSITION","EMPLOYER_NAME","EMPLOYER_CITY","EMPLOYER_STATE","PREVAILING_WAGE_1","CASE_SUBMITTED"],nrows=600000 )
#
# File c:\Users\Narayanan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File c:\Users\Narayanan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_base.py:465, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=458'>459</a>     raise ValueError(
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=459'>460</a>         "Engine should not be specified when passing "
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=460'>461</a>         "an ExcelFile - ExcelFile already has the engine set"
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=461'>462</a>     )
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=463'>464</a> try:
# --> <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=464'>465</a>     data = io.parse(
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=465'>466</a>         sheet_name=sheet_name,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=466'>467</a>         header=header,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=467'>468</a>         names=names,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=468'>469</a>         index_col=index_col,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=469'>470</a>         usecols=usecols,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=470'>471</a>         squeeze=squeeze,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=471'>472</a>         dtype=dtype,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=472'>473</a>         converters=converters,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=473'>474</a>         true_values=true_values,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=474'>475</a>         false_values=false_values,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=475'>476</a>         skiprows=skiprows,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=476'>477</a>         nrows=nrows,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=477'>478</a>         na_values=na_values,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=478'>479</a>         keep_default_na=keep_default_na,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=479'>480</a>         na_filter=na_filter,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=480'>481</a>         verbose=verbose,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=481'>482</a>         parse_dates=parse_dates,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=482'>483</a>         date_parser=date_parser,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=483'>484</a>         thousands=thousands,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=484'>485</a>         decimal=decimal,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=485'>486</a>         comment=comment,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=486'>487</a>         skipfooter=skipfooter,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=487'>488</a>         convert_float=convert_float,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=488'>489</a>         mangle_dupe_cols=mangle_dupe_cols,
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=489'>490</a>     )
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=490'>491</a> finally:
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=491'>492</a>     # make sure to close opened file handles
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=492'>493</a>     if should_close:
#
# File c:\Users\Narayanan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_base.py:1458, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, squeeze, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1423'>1424</a> def parse(
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1424'>1425</a>     self,
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1425'>1426</a>     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1444'>1445</a>     **kwds,
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1445'>1446</a> ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1446'>1447</a>     """
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1447'>1448</a>     Parse specified sheet(s) into a DataFrame.
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1448'>1449</a>
#    (...)
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1455'>1456</a>         DataFrame from the passed in Excel file.
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1456'>1457</a>     """
# -> <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1457'>1458</a>     return self._reader.parse(
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1458'>1459</a>         sheet_name=sheet_name,
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1459'>1460</a>         header=header,
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1460'>1461</a>         names=names,
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1461'>1462</a>         index_col=index_col,
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1462'>1463</a>         usecols=usecols,
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1463'>1464</a>         squeeze=squeeze,
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1464'>1465</a>         converters=converters,
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1465'>1466</a>         true_values=true_values,
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1466'>1467</a>         false_values=false_values,
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1467'>1468</a>         skiprows=skiprows,
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1468'>1469</a>         nrows=nrows,
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1469'>1470</a>         na_values=na_values,
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1470'>1471</a>         parse_dates=parse_dates,
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1471'>1472</a>         date_parser=date_parser,
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1472'>1473</a>         thousands=thousands,
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1473'>1474</a>         comment=comment,
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1474'>1475</a>         skipfooter=skipfooter,
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1475'>1476</a>         convert_float=convert_float,
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1476'>1477</a>         mangle_dupe_cols=mangle_dupe_cols,
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1477'>1478</a>         **kwds,
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=1478'>1479</a>     )
#
# File c:\Users\Narayanan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_base.py:638, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, squeeze, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=634'>635</a> else:  # assume an integer if not a string
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=635'>636</a>     sheet = self.get_sheet_by_index(asheetname)
# --> <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=637'>638</a> data = self.get_sheet_data(sheet, convert_float)
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=638'>639</a> if hasattr(sheet, "close"):
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=639'>640</a>     # pyxlsb opens two TemporaryFiles
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_base.py?line=640'>641</a>     sheet.close()
#
# File c:\Users\Narayanan\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\excel\_openpyxl.py:575, in OpenpyxlReader.get_sheet_data(self, sheet, convert_float)
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=572'>573</a> data: list[list[Scalar]] = []
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=573'>574</a> last_row_with_data = -1
# --> <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=574'>575</a> for row_number, row in enumerate(sheet.rows):
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=575'>576</a>     converted_row = [self._convert_cell(cell, convert_float) for cell in row]
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=576'>577</a>     while converted_row and converted_row[-1] == "":
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/io/excel/_openpyxl.py?line=577'>578</a>         # trim trailing empty elements
#
# File c:\Users\Narayanan\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\_read_only.py:79, in ReadOnlyWorksheet._cells_by_row(self, min_col, min_row, max_col, max_row, values_only)
#      <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_read_only.py?line=74'>75</a> src = self._get_source()
#      <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_read_only.py?line=75'>76</a> parser = WorkSheetParser(src, self._shared_strings,
#      <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_read_only.py?line=76'>77</a>                          data_only=self.parent.data_only, epoch=self.parent.epoch,
#      <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_read_only.py?line=77'>78</a>                          date_formats=self.parent._date_formats)
# ---> <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_read_only.py?line=78'>79</a> for idx, row in parser.parse():
#      <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_read_only.py?line=79'>80</a>     if max_row is not None and idx > max_row:
#      <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_read_only.py?line=80'>81</a>         break
#
# File c:\Users\Narayanan\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\_reader.py:144, in WorkSheetParser.parse(self)
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_reader.py?line=124'>125</a> properties = {
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_reader.py?line=125'>126</a>     PRINT_TAG: ('print_options', PrintOptions),
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_reader.py?line=126'>127</a>     MARGINS_TAG: ('page_margins', PageMargins),
#    (...)
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_reader.py?line=138'>139</a>
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_reader.py?line=139'>140</a> }
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_reader.py?line=141'>142</a> it = iterparse(self.source) # add a finaliser to close the source when this becomes possible
# --> <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_reader.py?line=143'>144</a> for _, element in it:
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_reader.py?line=144'>145</a>     tag_name = element.tag
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/site-packages/openpyxl/worksheet/_reader.py?line=145'>146</a>     if tag_name in dispatcher:
#
# File c:\Users\Narayanan\AppData\Local\Programs\Python\Python310\lib\xml\etree\ElementTree.py:1262, in iterparse.<locals>.iterator(source)
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/xml/etree/ElementTree.py?line=1259'>1260</a> yield from pullparser.read_events()
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/xml/etree/ElementTree.py?line=1260'>1261</a> # load event buffer
# -> <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/xml/etree/ElementTree.py?line=1261'>1262</a> data = source.read(16 * 1024)
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/xml/etree/ElementTree.py?line=1262'>1263</a> if not data:
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/xml/etree/ElementTree.py?line=1263'>1264</a>     break
#
# File c:\Users\Narayanan\AppData\Local\Programs\Python\Python310\lib\zipfile.py:925, in ZipExtFile.read(self, n)
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=922'>923</a> self._offset = 0
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=923'>924</a> while n > 0 and not self._eof:
# --> <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=924'>925</a>     data = self._read1(n)
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=925'>926</a>     if n < len(data):
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=926'>927</a>         self._readbuffer = data
#
# File c:\Users\Narayanan\AppData\Local\Programs\Python\Python310\lib\zipfile.py:993, in ZipExtFile._read1(self, n)
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=990'>991</a>     data = self._decompressor.unconsumed_tail
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=991'>992</a>     if n > len(data):
# --> <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=992'>993</a>         data += self._read2(n - len(data))
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=993'>994</a> else:
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=994'>995</a>     data = self._read2(n)
#
# File c:\Users\Narayanan\AppData\Local\Programs\Python\Python310\lib\zipfile.py:1025, in ZipExtFile._read2(self, n)
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=1021'>1022</a> n = max(n, self.MIN_READ_SIZE)
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=1022'>1023</a> n = min(n, self._compress_left)
# -> <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=1024'>1025</a> data = self._fileobj.read(n)
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=1025'>1026</a> self._compress_left -= len(data)
#    <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=1026'>1027</a> if not data:
#
# File c:\Users\Narayanan\AppData\Local\Programs\Python\Python310\lib\zipfile.py:745, in _SharedFile.read(self, n)
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=740'>741</a>     raise ValueError("Can't read from the ZIP file while there "
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=741'>742</a>             "is an open writing handle on it. "
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=742'>743</a>             "Close the writing handle before trying to read.")
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=743'>744</a> self._file.seek(self._pos)
# --> <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=744'>745</a> data = self._file.read(n)
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=745'>746</a> self._pos = self._file.tell()
#     <a href='file:///c%3A/Users/Narayanan/AppData/Local/Programs/Python/Python310/lib/zipfile.py?line=746'>747</a> return data
#
# KeyboardInterrupt:

# %%
df.head()
# Out:
#   CASE_STATUS CASE_SUBMITTED      VISA_CLASS                    JOB_TITLE  \
# 0   WITHDRAWN     2016-04-08            H-1B  ASSOCIATE CREATIVE DIRECTOR
# 1   WITHDRAWN     2017-07-14  E-3 Australian  ACCOUNT SUPERVISOR (MOTHER)
# 2   WITHDRAWN     2017-08-23  E-3 Australian  EXECUTIVE CREATIVE DIRECTOR
# 3   WITHDRAWN     2017-12-22  E-3 Australian      PROJECT MANAGEMENT LEAD
# 4   WITHDRAWN     2018-01-10  E-3 Australian        CREATIVE DIRECTOR, UX
#
#                              SOC_TITLE FULL_TIME_POSITION  \
# 0  ADVERTISING AND PROMOTIONS MANAGERS                  Y
# 1  ADVERTISING AND PROMOTIONS MANAGERS                  Y
# 2  ADVERTISING AND PROMOTIONS MANAGERS                  Y
# 3  ADVERTISING AND PROMOTIONS MANAGERS                  Y
# 4  ADVERTISING AND PROMOTIONS MANAGERS                  Y
#
#             EMPLOYER_NAME EMPLOYER_CITY EMPLOYER_STATE  PREVAILING_WAGE_1
# 0  R/GA MEDIA GROUP, INC.      NEW YORK             NY                NaN
# 1   MOTHER INDUSTRIES LLC      NEW YORK             NY                NaN
# 2  WE ARE UNLIMITED, INC.       CHICAGO             IL                NaN
# 3     HELLO ELEPHANT, LLC      BROOKLYN             NY                NaN
# 4     HELLO ELEPHANT, LLC      BROOKLYN             NY                NaN

# %%
df.drop_duplicates(inplace=True)

# %%
df['SOC_TITLE'].replace('COMPUTER SYSTEMS ANALYST','COMPUTER SYSTEMS ANALYSTS',inplace=True)

# %%
df['SOC_TITLE'].replace('SOFTWARE DEVELOPERS, APPLICATIONS','SOFTWARE DEVELOPER APPLICATIONS',inplace=True)

# %%
df['SOC_TITLE'].replace('SOFTARE DEVELOPERS, APPLICATIONS','SOFTWARE DEVELOPER APPLICATIONS',inplace=True)

# %%
df['SOC_TITLE'].replace('SOFTWARE DEVELOPERS, APPPLICATIONS','SOFTWARE DEVELOPER APPLICATIONS',inplace=True)

# %%
df['SOC_TITLE'].replace('SOFTWARE DEVELOPER APPLICATION','SOFTWARE DEVELOPER APPLICATIONS',inplace=True)

# %%
df['SOC_TITLE'].replace('MARKETING MANAGER','MARKETING MANAGERS',inplace=True)

# %%
df['SOC_TITLE'].replace('COMPUTER AND INFORMATION SYTEMS MANAGER','COMPUTER INFORMATION SYSTEMS MANAGERS',inplace=True)

# %%
df['SOC_TITLE'].replace('COMPUTER AND INFORMATION SYSTEMS MANAGER','COMPUTER INFORMATION SYSTEMS MANAGERS',inplace=True)

# %%
df['SOC_TITLE'].replace('SOFTWARE SEVELOPERS, APPPLICATIONS','SOFTWARE DEVELOPER APPLICATIONS',inplace=True)

# %%
#checking for outlier in 
plt.figure(figsize = (8,8))
sns.boxplot(x = 'PREVAILING_WAGE_1', data = df);

# %%
def removeoutliers(df,column):
  Q3=df[column].quantile(0.75)
  Q1=df[column].quantile(0.25)
  IQR=Q3-Q1
  upper=Q3+(1.5*IQR)
  lower=Q1-(1.5*IQR)
  df=df[(df[column]>lower)&(df[column]<upper)]
  return df

# %%
#We have removed the outliers in the PREVAILING_WAGE_1
df=removeoutliers(df,'PREVAILING_WAGE_1')

# %%
#After removal of outliers
plt.figure(figsize = (8,8))
sns.boxplot(x = 'PREVAILING_WAGE_1', data = df);

# %%
df.drop_duplicates(inplace=True)

# %%
df.info(null_counts=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: null_counts is deprecated. Use show_counts instead
#   """Entry point for launching an IPython kernel.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 519992 entries, 6 to 599999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   CASE_STATUS         519992 non-null  object
#  1   CASE_SUBMITTED      519992 non-null  datetime64[ns]
#  2   VISA_CLASS          519992 non-null  object
#  3   JOB_TITLE           519992 non-null  object
#  4   SOC_TITLE           519992 non-null  object
#  5   FULL_TIME_POSITION  519992 non-null  object
#  6   EMPLOYER_NAME       519986 non-null  object
#  7   EMPLOYER_CITY       519989 non-null  object
#  8   EMPLOYER_STATE      519964 non-null  object
#  9   PREVAILING_WAGE_1   519992 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 43.6+ MB

# %% [markdown]
# # WAGE DISTRIBUTION

# %%
total_certified_cases = df[df['CASE_STATUS']=='CERTIFIED']
certified_cases = total_certified_cases[total_certified_cases['PREVAILING_WAGE_1']<150000]

# %%
certified_cases.head(3)
# Out:
#    CASE_STATUS      CASE_SUBMITTED      VISA_CLASS            JOB_TITLE  \
# 28   CERTIFIED 2018-10-01 11:10:55  E-3 Australian   ACCOUNT SUPERVISOR
# 30   CERTIFIED 2018-10-03 11:24:44  E-3 Australian  ENGAGEMENT DIRECTOR
# 33   CERTIFIED 2018-10-04 09:56:24  E-3 Australian     ACCOUNT DIRECTOR
#
#                               SOC_TITLE FULL_TIME_POSITION     EMPLOYER_NAME  \
# 28  ADVERTISING AND PROMOTIONS MANAGERS                  Y  SID LEE USA, INC
# 30  ADVERTISING AND PROMOTIONS MANAGERS                  Y         HUGE, LLC
# 33  ADVERTISING AND PROMOTIONS MANAGERS                  Y  SID LEE USA, INC
#
#    EMPLOYER_CITY EMPLOYER_STATE  PREVAILING_WAGE_1
# 28   LOS ANGELES             CA           126755.0
# 30      BROOKLYN             NY           136178.0
# 33   LOS ANGELES             CA           126755.0

# %%
plt.figure(figsize=(30,10))
sns.distplot(certified_cases['PREVAILING_WAGE_1'],kde=True,hist_kws={"edgecolor": "black"})
plt.xlabel('PREVALING WAGES_1',size=20)
plt.ylabel('COUNT OF CERTIFIED CASES', size=20)
plt.title('WAGE DISTRIBUTION',size=20)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'WAGE DISTRIBUTION')

# %% [markdown]
# # H1-B COUNT OVER YEARS

# %%
import datetime
df['YEAR'] = pd.DatetimeIndex(df['CASE_SUBMITTED']).year

# %%
yearwise = df.groupby('YEAR').count()

# %%
#we can clearly see number of applications submitted for H1-B visa has increased drastically
plt.figure(figsize=(10,10))
sns.lineplot(data=yearwise['CASE_STATUS'],linewidth=1)

# %% [markdown]
# # MAIN BENEFICIARY OF H1-B VISA

# %%
#top 20 employers
top_twenty=certified_cases['EMPLOYER_NAME'].value_counts()[:20]
top_twenty.to_frame()
# Out:
#                                         EMPLOYER_NAME
# COGNIZANT TECHNOLOGY SOLUTIONS US CORP          27600
# INFOSYS LIMITED                                 15226
# TATA CONSULTANCY SERVICES LIMITED               11727
# ERNST & YOUNG U.S. LLP                           8568
# GOOGLE LLC                                       8262
# CAPGEMINI AMERICA INC                            7698
# DELOITTE CONSULTING LLP                          7403
# AMAZON.COM SERVICES, INC.                        6820
# MICROSOFT CORPORATION                            5554
# ACCENTURE LLP                                    5389
# HCL AMERICA, INC.                                4477
# WIPRO LIMITED                                    4076
# IBM CORPORATION                                  4057
# LARSEN & TOUBRO INFOTECH LIMITED                 3243
# TECH MAHINDRA (AMERICAS),INC.                    2866
# WAL-MART ASSOCIATES, INC.                        1982
# SYNTEL INC                                       1670
# COMPUNNEL SOFTWARE GROUP, INC.                   1619
# JPMORGAN CHASE & CO.                             1593
# IBM INDIA PRIVATE LIMITED                        1517

# %%
plt.figure(figsize=(30,20))
sns.barplot(x=top_twenty.values,y=top_twenty.index,color='blue')
plt.xlabel('COUNT OF CERTIFIED CASES',size=20)
plt.ylabel('EMPLOYERS', size=20)
plt.title('TOP BENIFICARIES',size=20)
plt.show()

# %% [markdown]
# # we take top 10 beneficiary of h1-b visa and see how the salary is distributed

# %%
f,axes = plt.subplots(nrows=10,ncols=1, figsize=(20,20),sharey=False)
rowcount=0
companies = top_twenty.index[:10]
for company in companies:
    axes[rowcount].set_title(company)
    wage = certified_cases[certified_cases['EMPLOYER_NAME']==company]['PREVAILING_WAGE_1']
    sns.distplot(wage ,ax=axes[rowcount],bins=100,hist_kws= {"edgecolor":"blue", "color": "#EE6666"}, kde=True)
    rowcount+=1
    
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # What are the top roles

# %%
top_roles = certified_cases['SOC_TITLE'].value_counts().head(10)
plt.figure(figsize=(15,15))
sns.barplot(y = top_roles.index ,x = top_roles.values ,color='m')
plt.xlabel('COUNT OF CERTIFIED CASES',size=20)
plt.ylabel('JOB ROLES', size=20)
plt.title('TOP JOB BENIFICARIES',size=20)
# Out:
# Text(0.5, 1.0, 'TOP JOB BENIFICARIES')

# %% [markdown]
# # Does having a full time job position influence the chance of getting the visa

# %%
certified_cases[certified_cases["FULL_TIME_POSITION"] == "Y"].count()
# Out:
# CASE_STATUS           485941
# CASE_SUBMITTED        485941
# VISA_CLASS            485941
# JOB_TITLE             485941
# SOC_TITLE             485941
# FULL_TIME_POSITION    485941
# EMPLOYER_NAME         485938
# EMPLOYER_CITY         485939
# EMPLOYER_STATE        485917
# PREVAILING_WAGE_1     485941
# dtype: int64

# %%
certified_cases['FULL_TIME_POSITION'].hist()

# %% [markdown]
# # How many people are granted the visa.

# %%
df.groupby('CASE_STATUS').count()
# Out:
#                      CASE_SUBMITTED  VISA_CLASS  JOB_TITLE  SOC_TITLE  \
# CASE_STATUS
# CERTIFIED                    485971      485971     485971     485971
# CERTIFIED-WITHDRAWN           16698       16698      16698      16698
# DENIED                         3766        3766       3766       3766
# WITHDRAWN                     13557       13557      13557      13557
#
#                      FULL_TIME_POSITION  EMPLOYER_NAME  EMPLOYER_CITY  \
# CASE_STATUS
# CERTIFIED                        485971         485968         485969
# CERTIFIED-WITHDRAWN               16698          16698          16698
# DENIED                             3766           3765           3766
# WITHDRAWN                         13557          13555          13556
#
#                      EMPLOYER_STATE  PREVAILING_WAGE_1    YEAR
# CASE_STATUS
# CERTIFIED                    485947             485971  485971
# CERTIFIED-WITHDRAWN           16695              16698   16698
# DENIED                         3766               3766    3766
# WITHDRAWN                     13556              13557   13557

# %%
df.groupby('CASE_STATUS').count().plot(kind = 'bar')
