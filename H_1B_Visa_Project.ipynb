# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"E:\DATA SCIENCE\Mini_Project\H-1B_Disclosure_Data_FY2019.xlsx")

# %%
df.head()
# Out:
#           CASE_NUMBER CASE_STATUS CASE_SUBMITTED DECISION_DATE  \
# 0  I-200-16092-327771   WITHDRAWN     2016-04-08    2019-04-30
# 1  I-203-17188-450729   WITHDRAWN     2017-07-14    2019-05-13
# 2  I-203-17229-572307   WITHDRAWN     2017-08-23    2019-04-30
# 3  I-203-17356-299648   WITHDRAWN     2017-12-22    2019-08-20
# 4  I-203-18008-577576   WITHDRAWN     2018-01-10    2019-04-15
#
#   ORIGINAL_CERT_DATE      VISA_CLASS                    JOB_TITLE SOC_CODE  \
# 0                NaT            H-1B  ASSOCIATE CREATIVE DIRECTOR  11-2011
# 1                NaT  E-3 Australian  ACCOUNT SUPERVISOR (MOTHER)  11-2011
# 2                NaT  E-3 Australian  EXECUTIVE CREATIVE DIRECTOR  11-2011
# 3                NaT  E-3 Australian      PROJECT MANAGEMENT LEAD  11-2011
# 4                NaT  E-3 Australian        CREATIVE DIRECTOR, UX  11-2011
#
#                              SOC_TITLE FULL_TIME_POSITION  ...  \
# 0  ADVERTISING AND PROMOTIONS MANAGERS                  Y  ...
# ...

# %%
df.shape
# Out:
# (664616, 260)

# %%
df.columns
# Out:
# Index(['CASE_NUMBER', 'CASE_STATUS', 'CASE_SUBMITTED', 'DECISION_DATE',
#        'ORIGINAL_CERT_DATE', 'VISA_CLASS', 'JOB_TITLE', 'SOC_CODE',
#        'SOC_TITLE', 'FULL_TIME_POSITION',
#        ...
#        'PW_OTHER_SOURCE_10', 'PW_NON-OES_YEAR_10', 'PW_SURVEY_PUBLISHER_10',
#        'PW_SURVEY_NAME_10', 'H-1B_DEPENDENT', 'WILLFUL_VIOLATOR',
#        'SUPPORT_H1B', 'STATUTORY_BASIS', 'MASTERS_EXEMPTION',
#        'PUBLIC_DISCLOSURE'],
#       dtype='object', length=260)

# %%
df.describe()
# Out:
#        TOTAL_WORKER_POSITIONS  CHANGE_PREVIOUS_EMPLOYMENT  \
# count           664614.000000               664616.000000
# mean                 1.604953                    0.121800
# std                  4.422125                    0.907174
# min                  1.000000                    0.000000
# 25%                  1.000000                    0.000000
# 50%                  1.000000                    0.000000
# 75%                  1.000000                    0.000000
# max                594.000000                  338.000000
#
#        NEW_CONCURRENT_EMPLOYMENT  CHANGE_EMPLOYER  AMENDED_PETITION  \
# count              664615.000000    664616.000000     664616.000000
# mean                    0.013208         0.254923          0.223296
# std                     0.283244         1.109193          0.896687
# min                     0.000000         0.000000          0.000000
# 25%                     0.000000         0.000000          0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664616 entries, 0 to 664615
# Columns: 260 entries, CASE_NUMBER to PUBLIC_DISCLOSURE
# dtypes: datetime64[ns](3), float64(81), int64(3), object(173)
# memory usage: 1.3+ GB

# %%
df = df[df.VISA_CLASS == 'H-1B']
df
# Out:
#                CASE_NUMBER CASE_STATUS      CASE_SUBMITTED  \
# 0       I-200-16092-327771   WITHDRAWN 2016-04-08 00:00:00
# 5       I-200-18150-993604   WITHDRAWN 2018-05-30 00:00:00
# 6       I-200-18289-307616   WITHDRAWN 2018-10-19 13:49:03
# 7       I-200-19015-877040   WITHDRAWN 2019-01-15 15:12:53
# 8       I-200-19031-693896   WITHDRAWN 2019-01-31 16:32:00
# ...                    ...         ...                 ...
# 664611  I-200-18282-647333   CERTIFIED 2018-10-09 18:10:32
# 664612  I-200-19046-203745      DENIED 2019-02-15 16:53:11
# 664613  I-200-19059-900658      DENIED 2019-02-28 01:11:11
# 664614  I-200-19063-784427      DENIED 2019-03-04 08:37:04
# 664615  I-200-19073-908844      DENIED 2019-03-14 08:14:46
#
#              DECISION_DATE ORIGINAL_CERT_DATE VISA_CLASS  \
# 0      2019-04-30 00:00:00                NaT       H-1B
# 5      2019-08-08 00:00:00                NaT       H-1B
# 6      2018-10-19 13:49:03                NaT       H-1B
# ...

# %%
df.EMPLOYER_COUNTRY.value_counts()
# Out:
# UNITED STATES OF AMERICA    621467
# CANADA                          25
# INDIA                            3
# ALBANIA                          2
# GUATEMALA                        2
# AUSTRALIA                        1
# TURKEY                           1
# AFGHANISTAN                      1
# Name: EMPLOYER_COUNTRY, dtype: int64

# %% [markdown]
# **Observations:**
#
# We Can find the Max,Min,Std,Mean etc

# %% [markdown]
# **Check Corr. With NUll Value**

# %%
df.corr()
# Out:
#                             TOTAL_WORKER_POSITIONS  \
# TOTAL_WORKER_POSITIONS                    1.000000
# CHANGE_PREVIOUS_EMPLOYMENT                0.502481
# NEW_CONCURRENT_EMPLOYMENT                 0.375202
# CHANGE_EMPLOYER                           0.570483
# AMENDED_PETITION                          0.597583
# ...                                            ...
# WAGE_RATE_OF_PAY_TO_10                    0.232075
# PREVAILING_WAGE_10                       -0.150264
# PW_OES_YEAR_10                           -0.149961
# PW_NON-OES_YEAR_10                       -0.125731
# PW_SURVEY_PUBLISHER_10                   -0.149961
#
#                             CHANGE_PREVIOUS_EMPLOYMENT  \
# TOTAL_WORKER_POSITIONS                        0.502481
# CHANGE_PREVIOUS_EMPLOYMENT                    1.000000
# NEW_CONCURRENT_EMPLOYMENT                     0.298329
# CHANGE_EMPLOYER                               0.410118
# AMENDED_PETITION                              0.513815
# ...

# %%
#get correlations of each features in dataset With Null Valuue
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# **Find Null Value**
#
#
# **Check Unique Value**

# %%
print("Unique values of each columns: ")
for col in df.columns:
  print(f"{col}: \n{df[col].unique()}\n")
# Out:
# Unique values of each columns:
# CASE_NUMBER:
# ['I-200-16092-327771' 'I-200-18150-993604' 'I-200-18289-307616' ...
#  'I-200-19059-900658' 'I-200-19063-784427' 'I-200-19073-908844']
#
# CASE_STATUS:
# ['WITHDRAWN' 'CERTIFIED-WITHDRAWN' 'CERTIFIED' 'DENIED']
#
# CASE_SUBMITTED:
# ['2016-04-08T00:00:00.000000000' '2018-05-30T00:00:00.000000000'
#  '2018-10-19T13:49:03.000000000' ... '2019-02-28T01:11:11.000000000'
#  '2019-03-04T08:37:04.000000000' '2019-03-14T08:14:46.000000000']
#
# DECISION_DATE:
# ['2019-04-30T00:00:00.000000000' '2019-08-08T00:00:00.000000000'
#  '2018-10-19T13:49:03.000000000' ... '2019-03-07T16:07:41.000000000'
#  '2019-03-08T12:01:58.000000000' '2019-03-19T11:41:04.000000000']
#
# ORIGINAL_CERT_DATE:
# [                          'NaT' '2017-09-08T00:00:00.000000000'
#  '2018-02-01T00:00:00.000000000' ... '2019-05-06T22:01:11.000000000'
#  '2019-09-09T22:00:54.000000000' '2019-09-12T22:00:59.000000000']
#
# VISA_CLASS:
# ['H-1B']
#
# JOB_TITLE:
# ...

# %%
df.isnull().mean()
# Out:
# CASE_NUMBER           0.000000
# CASE_STATUS           0.000000
# CASE_SUBMITTED        0.000000
# DECISION_DATE         0.000000
# ORIGINAL_CERT_DATE    0.929054
#                         ...
# WILLFUL_VIOLATOR      0.000034
# SUPPORT_H1B           0.632947
# STATUTORY_BASIS       0.679619
# MASTERS_EXEMPTION     0.998009
# PUBLIC_DISCLOSURE     0.050052
# Length: 260, dtype: float64

# %%
df.isnull().sum()
# Out:
# CASE_NUMBER                0
# CASE_STATUS                0
# CASE_SUBMITTED             0
# DECISION_DATE              0
# ORIGINAL_CERT_DATE    603033
#                        ...
# WILLFUL_VIOLATOR          22
# SUPPORT_H1B           410835
# STATUTORY_BASIS       441129
# MASTERS_EXEMPTION     647791
# PUBLIC_DISCLOSURE      32488
# Length: 260, dtype: int64

# %%
df=df.fillna(method='ffill',axis=0).fillna(0)

# %%
df
# Out:
#                CASE_NUMBER CASE_STATUS      CASE_SUBMITTED  \
# 0       I-200-16092-327771   WITHDRAWN 2016-04-08 00:00:00
# 5       I-200-18150-993604   WITHDRAWN 2018-05-30 00:00:00
# 6       I-200-18289-307616   WITHDRAWN 2018-10-19 13:49:03
# 7       I-200-19015-877040   WITHDRAWN 2019-01-15 15:12:53
# 8       I-200-19031-693896   WITHDRAWN 2019-01-31 16:32:00
# ...                    ...         ...                 ...
# 664611  I-200-18282-647333   CERTIFIED 2018-10-09 18:10:32
# 664612  I-200-19046-203745      DENIED 2019-02-15 16:53:11
# 664613  I-200-19059-900658      DENIED 2019-02-28 01:11:11
# 664614  I-200-19063-784427      DENIED 2019-03-04 08:37:04
# 664615  I-200-19073-908844      DENIED 2019-03-14 08:14:46
#
#              DECISION_DATE   ORIGINAL_CERT_DATE VISA_CLASS  \
# 0      2019-04-30 00:00:00                    0       H-1B
# 5      2019-08-08 00:00:00                    0       H-1B
# 6      2018-10-19 13:49:03                    0       H-1B
# ...

# %%
df.isnull().mean()
# Out:
# CASE_NUMBER           0.0
# CASE_STATUS           0.0
# CASE_SUBMITTED        0.0
# DECISION_DATE         0.0
# ORIGINAL_CERT_DATE    0.0
#                      ...
# WILLFUL_VIOLATOR      0.0
# SUPPORT_H1B           0.0
# STATUTORY_BASIS       0.0
# MASTERS_EXEMPTION     0.0
# PUBLIC_DISCLOSURE     0.0
# Length: 260, dtype: float64

# %%
df.dtypes
# Out:
# CASE_NUMBER                   object
# CASE_STATUS                   object
# CASE_SUBMITTED        datetime64[ns]
# DECISION_DATE         datetime64[ns]
# ORIGINAL_CERT_DATE            object
#                            ...
# WILLFUL_VIOLATOR              object
# SUPPORT_H1B                   object
# STATUTORY_BASIS               object
# MASTERS_EXEMPTION             object
# PUBLIC_DISCLOSURE             object
# Length: 260, dtype: object

# %%
df.corr()
# Out:
#                             TOTAL_WORKER_POSITIONS  \
# TOTAL_WORKER_POSITIONS                    1.000000
# CHANGE_PREVIOUS_EMPLOYMENT                0.502481
# NEW_CONCURRENT_EMPLOYMENT                 0.375201
# CHANGE_EMPLOYER                           0.570483
# AMENDED_PETITION                          0.597583
# ...                                            ...
# WAGE_RATE_OF_PAY_TO_10                   -0.013525
# PREVAILING_WAGE_10                       -0.002799
# PW_OES_YEAR_10                           -0.001260
# PW_NON-OES_YEAR_10                        0.002052
# PW_SURVEY_PUBLISHER_10                   -0.001260
#
#                             CHANGE_PREVIOUS_EMPLOYMENT  \
# TOTAL_WORKER_POSITIONS                        0.502481
# CHANGE_PREVIOUS_EMPLOYMENT                    1.000000
# NEW_CONCURRENT_EMPLOYMENT                     0.298329
# CHANGE_EMPLOYER                               0.410118
# AMENDED_PETITION                              0.513815
# ...

# %%
sns.pairplot(df)

# %%
#get correlations of each features in dataset
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")
