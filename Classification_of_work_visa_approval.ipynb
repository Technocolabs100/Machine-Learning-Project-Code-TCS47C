# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
# understanding the data

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
data.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
data.shape
# Out:
# (3000, 9)

# %%
data.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
data.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
data.nunique()
# Out:
# longitude              607
# latitude               587
# housing_median_age      52
# total_rooms           2215
# total_bedrooms        1055
# population            1802
# households            1026
# median_income         2578
# median_house_value    1784
# dtype: int64

# %%
data['total_rooms'].unique()
# Out:
# array([3885., 1510., 3589., ..., 4867.,  573., 5257.])

# %%
# cleaning data

# %%
data.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
housing=data.drop(['housing_median_age'],axis=1)

# %%
housing.head()
# Out:
#    longitude  latitude  total_rooms  total_bedrooms  population  households  \
# 0    -122.05     37.37       3885.0           661.0      1537.0       606.0
# 1    -118.30     34.26       1510.0           310.0       809.0       277.0
# 2    -117.81     33.78       3589.0           507.0      1484.0       495.0
# 3    -118.36     33.82         67.0            15.0        49.0        11.0
# 4    -119.67     36.33       1241.0           244.0       850.0       237.0
#
#    median_income  median_house_value
# 0         6.6085            344700.0
# 1         3.5990            176500.0
# 2         5.7934            270500.0
# 3         6.1359            330000.0
# 4         2.9375             81700.0

# %%
# relationship analysis

# %%
corelation = housing.corr()

# %%
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)

# %%
sns.pairplot(housing)

# %%
sns.relplot(x='longitude',y='latitude',hue='population',data=housing)

# %%
sns.distplot(housing['longitude'],bins=5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.catplot(x='longitude', kind = 'box', data = housing)
